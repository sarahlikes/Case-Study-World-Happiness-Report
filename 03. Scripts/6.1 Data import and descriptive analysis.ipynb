# %%
#01. Import Library
import pandas as pd
import numpy as np
import os

# %%
#02. Import dataframe
path=r'C:\Users\alexl\CareerFoundry\World Happiness Report 2015-2019'

# %%
df=pd.read_csv(r'C:\Users\alexl\Desktop\Happiness\solo combo happiness.csv', index_col=False)

# %%
#03. Data Cleaning and Wrangling
df.head()
# Out:
#    Year  Overall rank Country or region  Score  GDP per capita  \
# 0  2019             1           Finland  7.769           1.340
# 1  2019             2           Denmark  7.600           1.383
# 2  2019             3            Norway  7.554           1.488
# 3  2019             4           Iceland  7.494           1.380
# 4  2019             5       Netherlands  7.488           1.396
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           1.587                    0.986                         0.596
# 1           1.573                    0.996                         0.592
# 2           1.582                    1.028                         0.603
# 3           1.624                    1.026                         0.591
# 4           1.522                    0.999                         0.557
#
#    Generosity  Perceptions of corruption
# 0       0.153                      0.393
# 1       0.252                      0.410
# ...

# %%
#Checking nulls
df.isnull().sum()
# Out:
# Year                            0
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       1
# dtype: int64

# %%
#Dropping Nan Values
df_clean=df[df['Perceptions of corruption'].isnull()== False]

# %%
df_clean.shape
# Out:
# (781, 10)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 781 entries, 0 to 781
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          781 non-null    int64
#  1   Overall rank                  781 non-null    int64
#  2   Country or region             781 non-null    object
#  3   Score                         781 non-null    float64
#  4   GDP per capita                781 non-null    float64
#  5   Social support                781 non-null    float64
#  6   Healthy life expectancy       781 non-null    float64
#  7   Freedom to make life choices  781 non-null    float64
#  8   Generosity                    781 non-null    float64
#  9   Perceptions of corruption     781 non-null    float64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 67.1+ KB

# %%
df_clean
# Out:
#      Year  Overall rank Country or region  Score  GDP per capita  \
# 0    2019             1           Finland  7.769         1.34000
# 1    2019             2           Denmark  7.600         1.38300
# 2    2019             3            Norway  7.554         1.48800
# 3    2019             4           Iceland  7.494         1.38000
# 4    2019             5       Netherlands  7.488         1.39600
# ..    ...           ...               ...    ...             ...
# 777  2015           154            Rwanda  3.465         0.22208
# 778  2015           155             Benin  3.340         0.28665
# 779  2015           156             Syria  3.006         0.66320
# 780  2015           157           Burundi  2.905         0.01530
# 781  2015           158              Togo  2.839         0.20868
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           1.58700                  0.98600                       0.59600
# ...

# %%
df_clean.shape
# Out:
# (781, 10)

# %%
df_dups=df_clean[df_clean.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [Year, Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
#04. Saving and Exporting DF
df_clean.to_csv(os.path.join(path,'02. Data', 'Prepared Data', 'df_clean.csv'))
