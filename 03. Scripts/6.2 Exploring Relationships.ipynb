# %% [markdown]
#     # 6.2 Exploring Relationships

# %% [markdown]
# # 1. Set up a Jupyter notebook with visualization libraries, and import the cleaned data set you chose in the previous Exercise.

# %%
#Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
#Ensure charts are displayed in notebook
# %matplotlib inline

# %%
#Define path
path=r'C:\Users\alexl\CareerFoundry\World Happiness Report 2015-2019'

# %%
#Import data
df_clean=pd.read_csv(os.path.join(path, '02. Data', 'Prepared Data', 'df_clean.csv'))

# %%
#Checking matplotlib version
matplotlib.__version__
# Out:
# '3.7.1'

# %%
#Check Head
df_clean.head()
# Out:
#    Unnamed: 0  Year  Overall rank Country or region  Score  GDP per capita  \
# 0           0  2019             1           Finland  7.769           1.340
# 1           1  2019             2           Denmark  7.600           1.383
# 2           2  2019             3            Norway  7.554           1.488
# 3           3  2019             4           Iceland  7.494           1.380
# 4           4  2019             5       Netherlands  7.488           1.396
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           1.587                    0.986                         0.596
# 1           1.573                    0.996                         0.592
# 2           1.582                    1.028                         0.603
# 3           1.624                    1.026                         0.591
# 4           1.522                    0.999                         0.557
#
#    Generosity  Perceptions of corruption
# ...

# %%
#Rename columnss whose names are too long
df_clean.rename(columns={'Overall rank': 'Ranking', 'Country or region': 'Country', 'GDP per capita': 'GDP Per Capita', 'Social support': 'Family Support', 'Healthy life expectancy': 'Life Expectancy', 'Freedom to make life choices': 'Freedom', 'Perceptions of corruption': 'Peace'})
# Out:
#      Unnamed: 0  Year  Ranking      Country  Score  GDP Per Capita  \
# 0             0  2019        1      Finland  7.769         1.34000
# 1             1  2019        2      Denmark  7.600         1.38300
# 2             2  2019        3       Norway  7.554         1.48800
# 3             3  2019        4      Iceland  7.494         1.38000
# 4             4  2019        5  Netherlands  7.488         1.39600
# ..          ...   ...      ...          ...    ...             ...
# 776         777  2015      154       Rwanda  3.465         0.22208
# 777         778  2015      155        Benin  3.340         0.28665
# 778         779  2015      156        Syria  3.006         0.66320
# 779         780  2015      157      Burundi  2.905         0.01530
# 780         781  2015      158         Togo  2.839         0.20868
#
#      Family Support  Life Expectancy  Freedom  Generosity    Peace
# 0           1.58700          0.98600  0.59600     0.15300  0.39300
# ...

# %% [markdown]
# tried to rename, but didn't take*

# %% [markdown]
# # 2. Use the questions you defined in the previous task to pick out variables from your data set suitable for your exploratory visual analysis.
# For instance, discard “ID,” “date,” and “index” variables.

# %%
#Create a subset including: Country, Year, Score, GDP Per Capita, Family Support, Life Expectancy, Freedom, Generosity, Peace 
df_sub=df_clean[['Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']]

# %%
df_sub
# Out:
#      Score  GDP per capita  Social support  Healthy life expectancy  \
# 0    7.769         1.34000         1.58700                  0.98600
# 1    7.600         1.38300         1.57300                  0.99600
# 2    7.554         1.48800         1.58200                  1.02800
# 3    7.494         1.38000         1.62400                  1.02600
# 4    7.488         1.39600         1.52200                  0.99900
# ..     ...             ...             ...                      ...
# 776  3.465         0.22208         0.77370                  0.42864
# 777  3.340         0.28665         0.35386                  0.31910
# 778  3.006         0.66320         0.47489                  0.72193
# 779  2.905         0.01530         0.41587                  0.22396
# 780  2.839         0.20868         0.13995                  0.28443
#
#      Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.59600     0.15300                    0.39300
# ...

# %% [markdown]
# # 3. Create a correlation matrix heatmap (colored).
# Discuss what the coefficients in the plot mean in terms of the relationships between the variables.

# %%
#Create a subplot with matplotlib
f,ax=plt.subplots(figsize=(10,10))

#Create the correlation heatmap in seaborn by applying a heatmap onto correlation matrix and the subplots defined above.
corr_1=sns.heatmap(df_sub.corr(), annot=True, ax=ax)

# %%
#Saved subplot
corr_1.figure.savefig(os.path.join(path, '04. Analysis', 'Visualizations', 'corr_1.png'), bbox_inches='tight')

# %% [markdown]
# GDP Per Capita and Social Support are on the stronger end of the correlations, while Generosity is on the lower end.

# %% [markdown]
# # 4. Create a scatterplot (or plots) for the variables with the strongest correlations and examine the nature of their relationships.
# Discuss the output in a markdown cell.

# %%
# Create scatterplot for the "GDP Per Capita" and "Social Support" Columns.
sns.lmplot(x='GDP per capita', y='Social support', data= df_clean)

# %% [markdown]
# The correlation suggests that in many instances of higher GDP per capita, more opportunities for social support are also present.

# %% [markdown]
# # 5. Create a pair plot of the entire data set.
# Comment on the distribution of the variables and mark variables you’d like to explore further with an explanation of why.

# %%
#Check columns
df_clean.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Overall rank', 'Country or region', 'Score',
#        'GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
#Create pair plot
pairplot=sns.pairplot(df_clean)

# %% [markdown]
# Healthy life expectancy, Social support, and GDP per capita seem to have the strongest correlations. It might be interesting to explore which of the variables is most closely linked to Score or to each other. Also, More clarity surrounding what generosity entails.

# %% [markdown]
# # 6. Create a categorical plot and interpret the results.

# %% [markdown]
# GDP per capita vs Social support

# %%
sns.histplot(df_clean['Social support'], bins=20, kde=True)
# Out:
# <Axes: xlabel='Social support', ylabel='Count'>

# %%
#Apply flags
df_clean.loc[df_clean['Healthy life expectancy']<40, 'age']= 'young'

# %%
df_clean.loc[(df_clean['Healthy life expectancy']>=41)&(df_clean['Healthy life expectancy']<80), 'age']='middle aged'

# %%
df_clean.loc[df_clean['Healthy life expectancy']>=81, 'age']= 'old'

# %%
df_clean['age'].value_counts(dropna=False)
# Out:
# young    781
# Name: age, dtype: int64

# %%
#Create Categorical Plot
sns.set(style="ticks")
cat_1=sns.catplot(x='Healthy life expectancy', y='Social support', hue='age', data=df_clean)

# %% [markdown]
# Unclear why only young age took to the code, but there still seems to be a correlation where the more social support that is offered, the higher the life expectancy is, which makes sense and is to be expected.

# %% [markdown]
# # 7. Revisit the questions you generated in the previous task and write answers to those you can based on the exploration you’ve conducted so far. Add any new questions that may have arisen based on the early findings in your visual exploration.

# %% [markdown]
# GDP per capita does seem to have a very close correlation to the score, which may reveal a country to be "happier," or simply how the assessment is rating its happiness. A lot of assumed social dynamics appear to check out. For example, the less generosity, the higher perceived corruption. And, once a GDP per capita reaches a certain height, the more perceived corruption there is.

# %% [markdown]
# # 8. Define any hypotheses that you can at this point. You’ll be testing these later on.

# %% [markdown]
# Perception of corruption increases as GDP increases, though this pairing has a low correlation to score.
